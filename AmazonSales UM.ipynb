# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extract Data
data = pd.read_csv(r"C:\Users\Madhuri\OneDrive\Documents\projectum\Amazon Sales data.csv",encoding="utf-8")
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.shape
# Out:
# (100, 14)

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
#check for null values
pd.isnull(data).sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
# Transforming 'Order Date' & 'Ship Date' column to datetime format 
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
data.describe()
# Out:
#                 Order Date      Order ID            Ship Date   Units Sold  \
# count                  100  1.000000e+02                  100   100.000000
# mean   2013-09-16 14:09:36  5.550204e+08  2013-10-09 22:48:00  5128.710000
# min    2010-02-02 00:00:00  1.146066e+08  2010-02-25 00:00:00   124.000000
# 25%    2012-02-14 12:00:00  3.389225e+08  2012-02-24 18:00:00  2836.250000
# 50%    2013-07-12 12:00:00  5.577086e+08  2013-08-11 12:00:00  5382.500000
# 75%    2015-04-07 00:00:00  7.907551e+08  2015-04-28 00:00:00  7369.000000
# max    2017-05-22 00:00:00  9.940222e+08  2017-06-17 00:00:00  9925.000000
# std                    NaN  2.606153e+08                  NaN  2794.484562
#
#        Unit Price   Unit Cost  Total Revenue    Total Cost  Total Profit
# count  100.000000  100.000000   1.000000e+02  1.000000e+02  1.000000e+02
# mean   276.761300  191.048000   1.373488e+06  9.318057e+05  4.416820e+05
# min      9.330000    6.920000   4.870260e+03  3.612240e+03  1.258020e+03
# ...

# %%
# Convert 'Order Date' & 'Ship Date' column to datetime format 
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
# Extracting month and year from 'Order Date' column
data['Order Month'] = data['Order Date'].dt.month
data['Order Year'] = data['Order Date'].dt.year

# %%
# Calculate the number of 'Regions','Country'Item Types
region = data['Region'].nunique()
country = data['Country'].nunique()
item_type = data['Item Type'].nunique()
units_sold = data['Units Sold'].sum()
unit_cost = data['Unit Cost'].sum()
total_revenue = data['Total Revenue'].sum()
total_cost = data['Total Cost'].sum()
total_profit = data['Total Profit'].sum()
print('No. of Regions',region)
print('No. of Country',country)
print('No. of Item Types',item_type)
print('No. of Unit Sold',units_sold)
print('No. of Units Cost',unit_cost)
print('No. of Total Revenue',total_revenue)
print('No. of Total Cost',total_cost)
print('No. of Total Profit',total_profit)
# Out:
# No. of Regions 7
# No. of Country 76
# No. of Item Types 12
# No. of Unit Sold 512871
# No. of Units Cost 19104.8
# No. of Total Revenue 137348768.31
# No. of Total Cost 93180569.91000001
# No. of Total Profit 44168198.39999999

# %%
data.groupby(['Region','Sales Channel'])['Total Profit'].sum()
# Out:
# Region                             Sales Channel
# Asia                               Offline          3584286.33
#                                    Online           2529559.54
# Australia and Oceania              Offline          1886283.82
#                                    Online           2835876.21
# Central America and the Caribbean  Offline          2475814.99
#                                    Online            371092.86
# Europe                             Offline          5574539.91
#                                    Online           5508398.72
# Middle East and North Africa       Offline          2169081.08
#                                    Online           3592110.78
# North America                      Offline          1457942.76
# Sub-Saharan Africa                 Offline          7772777.78
#                                    Online           4410433.62
# Name: Total Profit, dtype: float64

# %%
# Grouping data by month and year and yearly monthly calculating total sales
monthly_sales = data.groupby(['Order Year', 'Order Month'])['Total Revenue'].sum().reset_index()
yearly_sales = data.groupby('Order Year')['Total Revenue'].sum().reset_index()
yearly_month_sales = data.groupby(['Order Year', 'Order Month'])['Total Revenue'].mean().unstack()

# %%
# Year wise Sales Trend
plt.figure(figsize=(10, 6))
sns.barplot(x='Order Year', y='Total Revenue', data=yearly_sales)
plt.title('Year-wise Sales Trends')
plt.xlabel('Year')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# According to this graph 2012 has high Sales and 2011 has low Sales

# %%
# Plotting yearly_monthly sales trend
yearly_monthly_sales = data.groupby(['Order Year', 'Order Month'])['Total Revenue'].sum().reset_index()

plt.figure(figsize=(12, 8))
sns.lineplot(data=yearly_monthly_sales, x='Order Month', y='Total Revenue', hue='Order Year', marker='o')
plt.title('Yearly Month-wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Madhuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Madhuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In july 2012 they have High Sales and
# In June 2011, August 2017 and September 2014 They have low Sales

# %%
# Groupby Total Profit by Region
TotalProfit_Region = data.groupby('Region')['Total Profit'].mean()

# %%
# Pie chart of Total Profit by Region
plt.figure(figsize=(8,8))
TotalProfit_Region.plot(kind='pie',autopct='%1.1f%%',startangle=90)
plt.title('Total Profit by Region')
# Out:
# Text(0.5, 1.0, 'Total Profit by Region')

# %% [markdown]
# Region wise Middle East And North Africa has high profit

# %%
# Groupby Total Revenue by Item Type
TotalRevenue_ItemType = data.groupby('Item Type')['Total Revenue'].sum()

# %%
# Bar chart for Total Revenue by Item Type
plt.figure(figsize=(8,3))
TotalRevenue_ItemType.plot(kind='bar')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.title('Average Revenue by Product type')
plt.grid(axis='y')

# %% [markdown]
# Cosmetics has high revenue

# %%
# Groupby Total Revenue by Item Type
TotalRevenue_SalesChannel = data.groupby('Sales Channel')['Total Revenue'].mean()

# %%
# Pie chart for Total Revenue by Item Type
plt.figure(figsize=(6,6))
plt.tight_layout()
TotalRevenue_SalesChannel.plot(kind='pie',autopct='%1.1f%%',startangle=90)
plt.title('Total Revenue by Sales Channel')
# Out:
# Text(0.5, 1.0, 'Total Revenue by Sales Channel')

# %% [markdown]
# Offline has high revenue

# %%
#Key metrics and factor analysis

key_metrics = data[['Total Revenue', 'Total Cost', 'Total Profit', 'Units Sold']]

# Descriptive statistics
print(key_metrics.describe())

# Correlation matrix
correlation_matrix = key_metrics.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Key Metrics')
plt.show()
# Out:
#        Total Revenue    Total Cost  Total Profit   Units Sold
# count   1.000000e+02  1.000000e+02  1.000000e+02   100.000000
# mean    1.373488e+06  9.318057e+05  4.416820e+05  5128.710000
# std     1.460029e+06  1.083938e+06  4.385379e+05  2794.484562
# min     4.870260e+03  3.612240e+03  1.258020e+03   124.000000
# 25%     2.687212e+05  1.688680e+05  1.214436e+05  2836.250000
# 50%     7.523144e+05  3.635664e+05  2.907680e+05  5382.500000
# 75%     2.212045e+06  1.613870e+06  6.358288e+05  7369.000000
# max     5.997055e+06  4.509794e+06  1.719922e+06  9925.000000

# %%
# Visualizing sales by other factors as needed
# Example: Sales by Order Priority
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Order Priority', y='Total Revenue', estimator=sum, ci=None)
plt.title('Total Sales by Order Priority')
plt.xlabel('Order Priority')
plt.ylabel('Total Sales')
plt.show()
# Out:
# C:\Users\Madhuri\AppData\Local\Temp\ipykernel_424\534634604.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='Order Priority', y='Total Revenue', estimator=sum, ci=None)

# %% [markdown]
# Conclusion :
# In july 2012 high priority, offline sale of ,item type wise cosmetics, in middle east and north africa has Highest Sale and
